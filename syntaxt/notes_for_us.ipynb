# %% [markdown]
# # ploting only particular year using timeseries

# %%
#plt.plot(with_no_null_WB[with_no_null_WB['date'].dt.year == 2024]['date'], with_no_null_WB[with_no_null_WB['date'].dt.year == 2024]['temperature(degree C)'], linewidth=1)
