# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd

# %%
df_bandarban = pd.read_csv('../1980-2024-dataset/Bandarban_historical_weather_1980_2024.csv')

# %%
df_bandarban.head()
# Out:
#     district  day  month  year  temperature(degree C)  feels_like(degree C)  \
# 0  Bandarban    1      1  1980                    NaN                   NaN
# 1  Bandarban    2      1  1980                    NaN                   NaN
# 2  Bandarban    3      1  1980                    NaN                   NaN
# 3  Bandarban    4      1  1980                    NaN                   NaN
# 4  Bandarban    5      1  1980                    NaN                   NaN
#
#    max_temperature(degree C)  minimum_temperature(degree C)  humidity  \
# 0                        0.0                            0.0       NaN
# 1                        0.0                            0.0       NaN
# 2                        0.0                            0.0       NaN
# 3                        0.0                            0.0       NaN
# 4                        0.0                            0.0       NaN
#
#    precipitation  windspeed  atmospheric_pressure  UV  solar_radiation  \
# 0            NaN        NaN                   NaN NaN              NaN
# 1            NaN        NaN                   NaN NaN              NaN
# 2            NaN        NaN                   NaN NaN              NaN
# 3            NaN        NaN                   NaN NaN              NaN
# 4            NaN        NaN                   NaN NaN              NaN
#
#    dew_point
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
desired_colmn = ['day', 'month', 'year', 'temperature(degree C)', 'humidity', 'solar_radiation']

df_bandarban = df_bandarban[desired_colmn]

# %%
import matplotlib.pyplot as plt

if 'date' not in df_bandarban.columns:
    df_bandarban['date'] = pd.to_datetime(df_bandarban[['year','month','day']])

min_date = df_bandarban['date'].min()
max_date = df_bandarban['date'].max()

# plt.figure(flagsize = (12, 6))
plt.figure(figsize= (12, 6))
plt.plot(df_bandarban['date'], df_bandarban['solar_radiation'], linewidth=0.2)
plt.xlabel('Date')
plt.ylabel('solar_radiation')
plt.title('solar_radiation (df_bandarban)')
plt.grid(True)
plt.tight_layout()
plt.show()
