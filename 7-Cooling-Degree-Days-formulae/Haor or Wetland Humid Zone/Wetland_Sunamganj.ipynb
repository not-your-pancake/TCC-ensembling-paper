# %% [markdown]
# # temperature

# %% [markdown]
# ## rf

# %% [markdown]
# ## rf-lstm

# %% [markdown]
# ## xgboost

# %% [markdown]
# ## light gbm

# %% [markdown]
# ## catboost

# %% [markdown]
# ## gru

# %% [markdown]
# ## lstm

# %% [markdown]
# ## ann

# %% [markdown]
# ## cnn-lstm

# %% [markdown]
# ## model chart temperature

# %% [markdown]
# ## best model temp

# %% [markdown]
# # humidity

# %% [markdown]
# ## rf

# %% [markdown]
# ## rf-lstm

# %% [markdown]
# ## xgboost

# %% [markdown]
# ## light gbm

# %% [markdown]
# ## catboost

# %% [markdown]
# ## gru

# %% [markdown]
# ## lstm

# %% [markdown]
# ## ann

# %% [markdown]
# ## cnn-lstm

# %% [markdown]
# ## model chart humidity

# %% [markdown]
# ## best model humidty

# %% [markdown]
# # dewpoint

# %% [markdown]
# ## rf

# %% [markdown]
# ## rf-lstm

# %% [markdown]
# ## xgboost

# %% [markdown]
# ## light gbm

# %% [markdown]
# ## catboost

# %% [markdown]
# ## gru

# %% [markdown]
# ## lstm

# %% [markdown]
# ## ann

# %% [markdown]
# ## cnn-lstm

# %% [markdown]
# ## model chart dew point

# %% [markdown]
# ## best model dewpoint

# %% [markdown]
# # solar radiation

# %% [markdown]
# ## rf

# %% [markdown]
# ## rf-lstm

# %% [markdown]
# ## xgboost

# %% [markdown]
# ## light gbm

# %% [markdown]
# ## catboost

# %% [markdown]
# ## gru

# %% [markdown]
# ## lstm

# %% [markdown]
# ## ann

# %% [markdown]
# ## cnn-lstm

# %% [markdown]
# ## model chart solar

# %% [markdown]
# ## best model solar
