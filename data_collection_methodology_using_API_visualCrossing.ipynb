# %% [markdown]
# Cell 1 : Write the Code to Fetch Data

# %%
import requests
import pandas as pd
from datetime import datetime
import time
import os  # For file paths

API_KEY = "YOUR_API_KEY_HERE"  # Replace with your actual API key

# Full list of 64 districts
DISTRICTS = [
    "Bagerhat,Bangladesh", "Bandarban,Bangladesh", "Barguna,Bangladesh", "Barisal,Bangladesh", "Bhola,Bangladesh",
    "Bogra,Bangladesh", "Brahmanbaria,Bangladesh", "Chandpur,Bangladesh", "Chittagong,Bangladesh", "Chuadanga,Bangladesh",
    "Comilla,Bangladesh", "Cox's Bazar,Bangladesh", "Dhaka,Bangladesh", "Dinajpur,Bangladesh", "Faridpur,Bangladesh",
    "Feni,Bangladesh", "Gaibandha,Bangladesh", "Gazipur,Bangladesh", "Gopalganj,Bangladesh", "Habiganj,Bangladesh",
    "Jamalpur,Bangladesh", "Jessore,Bangladesh", "Jhalokati,Bangladesh", "Jhenaidah,Bangladesh", "Joypurhat,Bangladesh",
    "Khagrachhari,Bangladesh", "Khulna,Bangladesh", "Kishoreganj,Bangladesh", "Kurigram,Bangladesh", "Kushtia,Bangladesh",
    "Lakshmipur,Bangladesh", "Lalmonirhat,Bangladesh", "Madaripur,Bangladesh", "Magura,Bangladesh", "Manikganj,Bangladesh",
    "Meherpur,Bangladesh", "Moulvibazar,Bangladesh", "Munshiganj,Bangladesh", "Mymensingh,Bangladesh", "Naogaon,Bangladesh",
    "Narail,Bangladesh", "Narayanganj,Bangladesh", "Narsingdi,Bangladesh", "Natore,Bangladesh", "Nawabganj,Bangladesh",
    "Netrakona,Bangladesh", "Nilphamari,Bangladesh", "Noakhali,Bangladesh", "Pabna,Bangladesh", "Panchagarh,Bangladesh",
    "Patuakhali,Bangladesh", "Pirojpur,Bangladesh", "Rajbari,Bangladesh", "Rajshahi,Bangladesh", "Rangamati,Bangladesh",
    "Rangpur,Bangladesh", "Satkhira,Bangladesh", "Shariatpur,Bangladesh", "Sherpur,Bangladesh", "Sirajganj,Bangladesh",
    "Sunamganj,Bangladesh", "Sylhet,Bangladesh", "Tangail,Bangladesh", "Thakurgaon,Bangladesh"
]  # Exactly 64

# Date range
START_YEAR = 1980
END_YEAR = 2024

# Function to fetch year (same as Cell 2)
def fetch_weather_year(location, year):
    start_date = f"{year}-01-01"
    end_date = f"{year}-12-31"
    url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{location}/{start_date}/{end_date}?unitGroup=metric&include=days&key={API_KEY}&contentType=json"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        days = data.get("days", [])
        if not days:
            print(f"No data for {location} {year}")
        else:
            print(f"Fetched {len(days)} days for {location} {year}")
        return days
    except Exception as e:
        print(f"Error for {location} {year}: {str(e)}")
        return []
# Out:
# Starting district: Bagerhat,Bangladesh
# Fetched 324 days for Bagerhat,Bangladesh 2025
# Saved 324 records for Bagerhat,Bangladesh to Bagerhat_historical_weather_2025.csv
#
# Starting district: Bandarban,Bangladesh
# Fetched 324 days for Bandarban,Bangladesh 2025
# Saved 324 records for Bandarban,Bangladesh to Bandarban_historical_weather_2025.csv
#
# Starting district: Barguna,Bangladesh
# Fetched 324 days for Barguna,Bangladesh 2025
# Saved 324 records for Barguna,Bangladesh to Barguna_historical_weather_2025.csv
#
# Starting district: Barisal,Bangladesh
# Fetched 324 days for Barisal,Bangladesh 2025
# Saved 324 records for Barisal,Bangladesh to Barisal_historical_weather_2025.csv
#
# Starting district: Bhola,Bangladesh
# Fetched 324 days for Bhola,Bangladesh 2025
# Saved 324 records for Bhola,Bangladesh to Bhola_historical_weather_2025.csv
#
# Starting district: Bogra,Bangladesh
# Fetched 324 days for Bogra,Bangladesh 2025
# Saved 324 records for Bogra,Bangladesh to Bogra_historical_weather_2025.csv
#
# Starting district: Brahmanbaria,Bangladesh
# Fetched 324 days for Brahmanbaria,Bangladesh 2025
# Saved 324 records for Brahmanbaria,Bangladesh to Brahmanbaria_historical_weather_2025.csv
#
# Starting district: Chandpur,Bangladesh
# Fetched 324 days for Chandpur,Bangladesh 2025
# Saved 324 records for Chandpur,Bangladesh to Chandpur_historical_weather_2025.csv
#
# Starting district: Chittagong,Bangladesh
# Fetched 324 days for Chittagong,Bangladesh 2025
# Saved 324 records for Chittagong,Bangladesh to Chittagong_historical_weather_2025.csv
#
# Starting district: Chuadanga,Bangladesh
# Fetched 324 days for Chuadanga,Bangladesh 2025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 59
#      57     year_data = fetch_weather_year(location, year)
#      58     all_data.extend(year_data)
# ---> 59     time.sleep(2)  # Optional delay to avoid rate limits
#      61 # Process the data
#      62 extracted_data = []
#
# KeyboardInterrupt:

# %% [markdown]
# Cell 2 : Function to Fetch One Year's Data

# %%
# Choose which districts to fetch (e.g., first 5 for testing)
districts_to_fetch = DISTRICTS[:5]  # Change to DISTRICTS for all

for location in districts_to_fetch:
    print(f"\nStarting district: {location}")
    all_data = []  # Reset for each district
    
    for year in range(START_YEAR, END_YEAR + 1):
        year_data = fetch_weather_year(location, year)
        all_data.extend(year_data)
        time.sleep(2)  # Delay
    
    # Process immediately for this district
    extracted_data = []
    for day in all_data:
        date_str = day.get("datetime")
        if date_str:
            dt = datetime.strptime(date_str, "%Y-%m-%d")
            if dt > datetime(2024, 12, 31):
                continue
            day_val = dt.day
            month_val = dt.month
            year_val = dt.year
        else:
            day_val = month_val = year_val = None
        
        row = {
            "district": location.split(",")[0],  # Add district column
            "day": day_val,
            "month": month_val,
            "year": year_val,
            "temperature(degree C)": day.get("temp"), 
            "feels_like(degree C)": day.get("feelslike"),
            "max_temperature(degree C)": day.get("tempmax"),
            "minimum_temperature(degree C)": day.get("tempmin"),
            "humidity": day.get("humidity"),
            "precipitation": day.get("precip"),
            "windspeed": day.get("windspeed"),
            "atmospheric_pressure": day.get("pressure"),
            "UV": day.get("uvindex"),
            "solar_radiation": day.get("solarradiation"),
            "dew_point": day.get("dew")
        }
        extracted_data.append(row)
    
    # Save per district
    df = pd.DataFrame(extracted_data)
    filename = f"{location.split(',')[0]}_historical_weather_1980_2024.csv"
    df.to_csv(filename, index=False)
    print(f"Saved {len(df)} records for {location} to {filename}")
    
    # Optional: Combine all so far
    # all_files = [f for f in os.listdir('.') if f.endswith('.csv')]
    # combined_df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    # combined_df.to_csv("all_bangladesh_weather_1980_2024.csv", index=False)
# Out:
# Starting district: Bagerhat,Bangladesh
# Fetched 366 days for Bagerhat,Bangladesh 1980
# Fetched 365 days for Bagerhat,Bangladesh 1981
# Fetched 365 days for Bagerhat,Bangladesh 1982
# Fetched 365 days for Bagerhat,Bangladesh 1983
# Fetched 366 days for Bagerhat,Bangladesh 1984
# Fetched 365 days for Bagerhat,Bangladesh 1985
# Fetched 365 days for Bagerhat,Bangladesh 1986
# Fetched 365 days for Bagerhat,Bangladesh 1987
# Fetched 366 days for Bagerhat,Bangladesh 1988
# Fetched 365 days for Bagerhat,Bangladesh 1989
# Fetched 365 days for Bagerhat,Bangladesh 1990
# Fetched 365 days for Bagerhat,Bangladesh 1991
# Fetched 366 days for Bagerhat,Bangladesh 1992
# Fetched 365 days for Bagerhat,Bangladesh 1993
# Fetched 365 days for Bagerhat,Bangladesh 1994
# Fetched 365 days for Bagerhat,Bangladesh 1995
# Fetched 366 days for Bagerhat,Bangladesh 1996
# Fetched 365 days for Bagerhat,Bangladesh 1997
# Fetched 365 days for Bagerhat,Bangladesh 1998
# Fetched 365 days for Bagerhat,Bangladesh 1999
# Fetched 366 days for Bagerhat,Bangladesh 2000
# Fetched 365 days for Bagerhat,Bangladesh 2001
# Fetched 365 days for Bagerhat,Bangladesh 2002
# Fetched 365 days for Bagerhat,Bangladesh 2003
# Fetched 366 days for Bagerhat,Bangladesh 2004
# Fetched 365 days for Bagerhat,Bangladesh 2005
# Fetched 365 days for Bagerhat,Bangladesh 2006
# Fetched 365 days for Bagerhat,Bangladesh 2007
# Fetched 366 days for Bagerhat,Bangladesh 2008
# Fetched 365 days for Bagerhat,Bangladesh 2009
# Fetched 365 days for Bagerhat,Bangladesh 2010
# Fetched 365 days for Bagerhat,Bangladesh 2011
# Fetched 366 days for Bagerhat,Bangladesh 2012
# Fetched 365 days for Bagerhat,Bangladesh 2013
# Fetched 365 days for Bagerhat,Bangladesh 2014
# Fetched 365 days for Bagerhat,Bangladesh 2015
# Fetched 366 days for Bagerhat,Bangladesh 2016
# Fetched 365 days for Bagerhat,Bangladesh 2017
# Fetched 365 days for Bagerhat,Bangladesh 2018
# Fetched 365 days for Bagerhat,Bangladesh 2019
# Fetched 366 days for Bagerhat,Bangladesh 2020
# Fetched 365 days for Bagerhat,Bangladesh 2021
# Fetched 365 days for Bagerhat,Bangladesh 2022
# Fetched 365 days for Bagerhat,Bangladesh 2023
# Fetched 366 days for Bagerhat,Bangladesh 2024
# Saved 16437 records for Bagerhat,Bangladesh to Bagerhat_historical_weather_1980_2024.csv
#
# Starting district: Bandarban,Bangladesh
# Fetched 366 days for Bandarban,Bangladesh 1980
# Fetched 365 days for Bandarban,Bangladesh 1981
# Fetched 365 days for Bandarban,Bangladesh 1982
# Fetched 366 days for Bhola,Bangladesh 2020
# Fetched 365 days for Bhola,Bangladesh 2021
# Fetched 365 days for Bhola,Bangladesh 2022
# Fetched 365 days for Bhola,Bangladesh 2023
# Fetched 366 days for Bhola,Bangladesh 2024
# Saved 16437 records for Bhola,Bangladesh to Bhola_historical_weather_1980_2024.csv

# %% [markdown]
# cell 2.2 : Loop to Fetch All Years (in Batches)

# %%
# Choose which districts to fetch (e.g., first 5 for testing)
districts_to_fetch = DISTRICTS[5:10]  # Bogra to Chuadanga

for location in districts_to_fetch:
    print(f"\nStarting district: {location}")
    all_data = []  # Reset for each district
    
    for year in range(START_YEAR, END_YEAR + 1):
        year_data = fetch_weather_year(location, year)
        all_data.extend(year_data)
        time.sleep(2)  # Delay
    
    # Process immediately for this district
    extracted_data = []
    for day in all_data:
        date_str = day.get("datetime")
        if date_str:
            dt = datetime.strptime(date_str, "%Y-%m-%d")
            if dt > datetime(2024, 12, 31):
                continue
            day_val = dt.day
            month_val = dt.month
            year_val = dt.year
        else:
            day_val = month_val = year_val = None
        
        row = {
            "district": location.split(",")[0],  # Add district column
            "day": day_val,
            "month": month_val,
            "year": year_val,
            "temperature(degree C)": day.get("temp"),
            "feels_like(degree C)": day.get("feelslike"),
            "max_temperature(degree C)": day.get("tempmax"),
            "minimum_temperature(degree C)": day.get("tempmin"),
            "humidity": day.get("humidity"),
            "precipitation": day.get("precip"),
            "windspeed": day.get("windspeed"),
            "atmospheric_pressure": day.get("pressure"),
            "UV": day.get("uvindex"),
            "solar_radiation": day.get("solarradiation"),
            "dew_point": day.get("dew")
        }
        extracted_data.append(row)
    
    # Save per district
    df = pd.DataFrame(extracted_data)
    filename = f"{location.split(',')[0]}_historical_weather_1980_2024.csv"
    df.to_csv(filename, index=False)
    print(f"Saved {len(df)} records for {location} to {filename}")
    
    # Optional: Combine all so far
    # all_files = [f for f in os.listdir('.') if f.endswith('.csv')]
    # combined_df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    # combined_df.to_csv("all_bangladesh_weather_1980_2024.csv", index=False)
# Out:
# Starting district: Bogra,Bangladesh
# Fetched 366 days for Bogra,Bangladesh 1980
# Fetched 365 days for Bogra,Bangladesh 1981
# Fetched 365 days for Bogra,Bangladesh 1982
# Fetched 365 days for Bogra,Bangladesh 1983
# Fetched 366 days for Bogra,Bangladesh 1984
# Fetched 365 days for Bogra,Bangladesh 1985
# Fetched 365 days for Bogra,Bangladesh 1986
# Fetched 365 days for Bogra,Bangladesh 1987
# Fetched 366 days for Bogra,Bangladesh 1988
# Fetched 365 days for Bogra,Bangladesh 1989
# Fetched 365 days for Bogra,Bangladesh 1990
# Fetched 365 days for Bogra,Bangladesh 1991
# Fetched 366 days for Bogra,Bangladesh 1992
# Fetched 365 days for Bogra,Bangladesh 1993
# Fetched 365 days for Bogra,Bangladesh 1994
# Fetched 365 days for Bogra,Bangladesh 1995
# Fetched 366 days for Bogra,Bangladesh 1996
# Fetched 365 days for Bogra,Bangladesh 1997
# Saved 16437 records for Chittagong,Bangladesh to Chittagong_historical_weather_1980_2024.csv
#
# Starting district: Chuadanga,Bangladesh
# Fetched 366 days for Chuadanga,Bangladesh 1980
# Fetched 365 days for Chuadanga,Bangladesh 1981
# Fetched 365 days for Chuadanga,Bangladesh 1982
# Fetched 365 days for Chuadanga,Bangladesh 1983
# Fetched 366 days for Chuadanga,Bangladesh 1984
# Fetched 365 days for Chuadanga,Bangladesh 1985
# Fetched 365 days for Chuadanga,Bangladesh 1986
# Fetched 365 days for Chuadanga,Bangladesh 1987
# Fetched 366 days for Chuadanga,Bangladesh 1988
# Fetched 365 days for Chuadanga,Bangladesh 1989
# Fetched 365 days for Chuadanga,Bangladesh 1990
# Fetched 365 days for Chuadanga,Bangladesh 1991
# Fetched 366 days for Chuadanga,Bangladesh 1992
# Fetched 365 days for Chuadanga,Bangladesh 1993
# Fetched 365 days for Chuadanga,Bangladesh 1994
# Fetched 365 days for Chuadanga,Bangladesh 1995
# Fetched 366 days for Chuadanga,Bangladesh 1996
# Fetched 365 days for Chuadanga,Bangladesh 1997
# Fetched 365 days for Chuadanga,Bangladesh 1998
# Fetched 365 days for Chuadanga,Bangladesh 1999
# Fetched 366 days for Chuadanga,Bangladesh 2000
# Fetched 365 days for Chuadanga,Bangladesh 2001
# Fetched 365 days for Chuadanga,Bangladesh 2002
# Fetched 365 days for Chuadanga,Bangladesh 2003
# Fetched 366 days for Chuadanga,Bangladesh 2004
# Fetched 365 days for Chuadanga,Bangladesh 2005
# Fetched 365 days for Chuadanga,Bangladesh 2006
# Fetched 365 days for Chuadanga,Bangladesh 2007
# Fetched 366 days for Chuadanga,Bangladesh 2008
# Fetched 365 days for Chuadanga,Bangladesh 2009
# Fetched 365 days for Chuadanga,Bangladesh 2010
# Fetched 365 days for Chuadanga,Bangladesh 2011
# Fetched 366 days for Chuadanga,Bangladesh 2012
# Fetched 365 days for Chuadanga,Bangladesh 2013
# Fetched 365 days for Chuadanga,Bangladesh 2014
# Fetched 365 days for Chuadanga,Bangladesh 2015
# Fetched 366 days for Chuadanga,Bangladesh 2016
# Fetched 365 days for Chuadanga,Bangladesh 2017
# Fetched 365 days for Chuadanga,Bangladesh 2018
# Fetched 365 days for Chuadanga,Bangladesh 2019
# Fetched 366 days for Chuadanga,Bangladesh 2020
# Fetched 365 days for Chuadanga,Bangladesh 2021
# Fetched 365 days for Chuadanga,Bangladesh 2022
# Fetched 365 days for Chuadanga,Bangladesh 2023
# Fetched 366 days for Chuadanga,Bangladesh 2024
# Saved 16437 records for Chuadanga,Bangladesh to Chuadanga_historical_weather_1980_2024.csv

# %% [markdown]
# cell 2.3 : Loop to Fetch All Years (in Batches)

# %%
# Choose which districts to fetch (e.g., first 5 for testing)
districts_to_fetch = DISTRICTS[10:15]  # Comilla to Faridpur

for location in districts_to_fetch:
    print(f"\nStarting district: {location}")
    all_data = []  # Reset for each district
    
    for year in range(START_YEAR, END_YEAR + 1):
        year_data = fetch_weather_year(location, year)
        all_data.extend(year_data)
        time.sleep(2)  # Delay
    
    # Process immediately for this district
    extracted_data = []
    for day in all_data:
        date_str = day.get("datetime")
        if date_str:
            dt = datetime.strptime(date_str, "%Y-%m-%d")
            if dt > datetime(2024, 12, 31):
                continue
            day_val = dt.day
            month_val = dt.month
            year_val = dt.year
        else:
            day_val = month_val = year_val = None
        
        row = {
            "district": location.split(",")[0],  # Add district column
            "day": day_val,
            "month": month_val,
            "year": year_val,
            "temperature(degree C)": day.get("temp"),
            "feels_like(degree C)": day.get("feelslike"),
            "max_temperature(degree C)": day.get("tempmax"),
            "minimum_temperature(degree C)": day.get("tempmin"),
            "humidity": day.get("humidity"),
            "precipitation": day.get("precip"),
            "windspeed": day.get("windspeed"),
            "atmospheric_pressure": day.get("pressure"),
            "UV": day.get("uvindex"),
            "solar_radiation": day.get("solarradiation"),
            "dew_point": day.get("dew")
        }
        extracted_data.append(row)
    
    # Save per district
    df = pd.DataFrame(extracted_data)
    filename = f"{location.split(',')[0]}_historical_weather_1980_2024.csv"
    df.to_csv(filename, index=False)
    print(f"Saved {len(df)} records for {location} to {filename}")
    
    # Optional: Combine all so far
    # all_files = [f for f in os.listdir('.') if f.endswith('.csv')]
    # combined_df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    # combined_df.to_csv("all_bangladesh_weather_1980_2024.csv", index=False)
# Out:
# Starting district: Comilla,Bangladesh
# Fetched 366 days for Comilla,Bangladesh 1980
# Fetched 365 days for Comilla,Bangladesh 1981
# Fetched 365 days for Comilla,Bangladesh 1982
# Fetched 365 days for Comilla,Bangladesh 1983
# Fetched 366 days for Comilla,Bangladesh 1984
# Fetched 365 days for Comilla,Bangladesh 1985
# Fetched 365 days for Comilla,Bangladesh 1986
# Fetched 365 days for Comilla,Bangladesh 1987
# Fetched 366 days for Comilla,Bangladesh 1988
# Fetched 365 days for Comilla,Bangladesh 1989
# Fetched 365 days for Comilla,Bangladesh 1990
# Fetched 365 days for Comilla,Bangladesh 1991
# Fetched 366 days for Comilla,Bangladesh 1992
# Fetched 365 days for Comilla,Bangladesh 1993
# Fetched 365 days for Comilla,Bangladesh 1994
# Fetched 365 days for Comilla,Bangladesh 1995
# Fetched 366 days for Comilla,Bangladesh 1996
# Fetched 365 days for Comilla,Bangladesh 1997
# Fetched 365 days for Comilla,Bangladesh 1998
# Fetched 365 days for Comilla,Bangladesh 1999
# Fetched 366 days for Comilla,Bangladesh 2000
# Fetched 365 days for Comilla,Bangladesh 2001
# Fetched 365 days for Comilla,Bangladesh 2002
# Fetched 365 days for Comilla,Bangladesh 2003
# Fetched 366 days for Comilla,Bangladesh 2004
# Fetched 365 days for Comilla,Bangladesh 2005
# Fetched 365 days for Comilla,Bangladesh 2006
# Fetched 365 days for Comilla,Bangladesh 2007
# Fetched 366 days for Comilla,Bangladesh 2008
# Fetched 365 days for Comilla,Bangladesh 2009
# Fetched 365 days for Comilla,Bangladesh 2010
# Fetched 365 days for Comilla,Bangladesh 2011
# Fetched 365 days for Faridpur,Bangladesh 1990
# Fetched 365 days for Faridpur,Bangladesh 1991
# Fetched 366 days for Faridpur,Bangladesh 1992
# Fetched 365 days for Faridpur,Bangladesh 1993
# Fetched 365 days for Faridpur,Bangladesh 1994
# Fetched 365 days for Faridpur,Bangladesh 1995
# Fetched 366 days for Faridpur,Bangladesh 1996
# Fetched 365 days for Faridpur,Bangladesh 1997
# Fetched 365 days for Faridpur,Bangladesh 1998
# Fetched 365 days for Faridpur,Bangladesh 1999
# Fetched 366 days for Faridpur,Bangladesh 2000
# Fetched 365 days for Faridpur,Bangladesh 2001
# Fetched 365 days for Faridpur,Bangladesh 2002
# Fetched 365 days for Faridpur,Bangladesh 2003
# Fetched 366 days for Faridpur,Bangladesh 2004
# Fetched 365 days for Faridpur,Bangladesh 2005
# Fetched 365 days for Faridpur,Bangladesh 2006
# Fetched 365 days for Faridpur,Bangladesh 2007
# Fetched 366 days for Faridpur,Bangladesh 2008
# Fetched 365 days for Faridpur,Bangladesh 2009
# Fetched 365 days for Faridpur,Bangladesh 2010
# Fetched 365 days for Faridpur,Bangladesh 2011
# Fetched 366 days for Faridpur,Bangladesh 2012
# Fetched 365 days for Faridpur,Bangladesh 2013
# Fetched 365 days for Faridpur,Bangladesh 2014
# Fetched 365 days for Faridpur,Bangladesh 2015
# Fetched 366 days for Faridpur,Bangladesh 2016
# Fetched 365 days for Faridpur,Bangladesh 2017
# Fetched 365 days for Faridpur,Bangladesh 2018
# Fetched 365 days for Faridpur,Bangladesh 2019
# Fetched 366 days for Faridpur,Bangladesh 2020
# Fetched 365 days for Faridpur,Bangladesh 2021
# Fetched 365 days for Faridpur,Bangladesh 2022
# Fetched 365 days for Faridpur,Bangladesh 2023
# Fetched 366 days for Faridpur,Bangladesh 2024
# Saved 16437 records for Faridpur,Bangladesh to Faridpur_historical_weather_1980_2024.csv

# %%
# Choose the last district to fetch
districts_to_fetch = ["Thakurgaon,Bangladesh"]

for location in districts_to_fetch:
    print(f"\nStarting district: {location}")
    all_data = []  # Reset for each district
    
    for year in range(1980, 2025):  # 2025 is exclusive, stops at 2024
        year_data = fetch_weather_year(location, year)
        all_data.extend(year_data)
        time.sleep(2)  # Delay
    
    # Process immediately for this district
    extracted_data = []
    for day in all_data:
        date_str = day.get("datetime")
        if date_str:
            dt = datetime.strptime(date_str, "%Y-%m-%d")
            if dt > datetime(2024, 12, 31):
                continue
            day_val = dt.day
            month_val = dt.month
            year_val = dt.year
        else:
            day_val = month_val = year_val = None
        
        row = {
            "district": location.split(",")[0],
            "day": day_val,
            "month": month_val,
            "year": year_val,
            "temperature(degree C)": day.get("temp"),
            "feels_like(degree C)": day.get("feelslike"),
            "max_temperature(degree C)": day.get("tempmax"),
            "minimum_temperature(degree C)": day.get("tempmin"),
            "humidity": day.get("humidity"),
            "precipitation": day.get("precip"),
            "windspeed": day.get("windspeed"),
            "atmospheric_pressure": day.get("pressure"),
            "UV": day.get("uvindex"),
            "solar_radiation": day.get("solarradiation"),
            "dew_point": day.get("dew")
        }
        extracted_data.append(row)
    
    # Save per district
    df = pd.DataFrame(extracted_data)
    filename = f"{location.split(',')[0]}_historical_weather_1980_2024.csv"
    if os.path.exists(filename):
        print(f"Skipping {location}, file exists")
        continue
    df.to_csv(filename, index=False)
    print(f"Saved {len(df)} records for {location} to {filename}")
# Out:
# Starting district: Thakurgaon,Bangladesh
# Fetched 366 days for Thakurgaon,Bangladesh 1980
# Fetched 365 days for Thakurgaon,Bangladesh 1981
# Fetched 365 days for Thakurgaon,Bangladesh 1982
# Fetched 365 days for Thakurgaon,Bangladesh 1983
# Fetched 366 days for Thakurgaon,Bangladesh 1984
# Fetched 365 days for Thakurgaon,Bangladesh 1985
# Fetched 365 days for Thakurgaon,Bangladesh 1986
# Fetched 365 days for Thakurgaon,Bangladesh 1987
# Fetched 366 days for Thakurgaon,Bangladesh 1988
# Fetched 365 days for Thakurgaon,Bangladesh 1989
# Fetched 365 days for Thakurgaon,Bangladesh 1990
# Fetched 365 days for Thakurgaon,Bangladesh 1991
# Fetched 366 days for Thakurgaon,Bangladesh 1992
# Fetched 365 days for Thakurgaon,Bangladesh 1993
# Fetched 365 days for Thakurgaon,Bangladesh 1994
# Fetched 365 days for Thakurgaon,Bangladesh 1995
# Fetched 366 days for Thakurgaon,Bangladesh 1996
# Fetched 365 days for Thakurgaon,Bangladesh 1997
# Fetched 365 days for Thakurgaon,Bangladesh 1998
# Fetched 365 days for Thakurgaon,Bangladesh 1999
# Fetched 366 days for Thakurgaon,Bangladesh 2000
# Fetched 365 days for Thakurgaon,Bangladesh 2001
# Fetched 365 days for Thakurgaon,Bangladesh 2002
# Fetched 365 days for Thakurgaon,Bangladesh 2003
# Fetched 366 days for Thakurgaon,Bangladesh 2004
# Fetched 365 days for Thakurgaon,Bangladesh 2005
# Fetched 365 days for Thakurgaon,Bangladesh 2006
# Fetched 365 days for Thakurgaon,Bangladesh 2007
# Fetched 366 days for Thakurgaon,Bangladesh 2008
# Fetched 365 days for Thakurgaon,Bangladesh 2009
# Fetched 365 days for Thakurgaon,Bangladesh 2010
# Fetched 365 days for Thakurgaon,Bangladesh 2011
# Fetched 366 days for Thakurgaon,Bangladesh 2012
# Fetched 365 days for Thakurgaon,Bangladesh 2013
# Fetched 365 days for Thakurgaon,Bangladesh 2014
# Fetched 365 days for Thakurgaon,Bangladesh 2015
# Fetched 366 days for Thakurgaon,Bangladesh 2016
# Fetched 365 days for Thakurgaon,Bangladesh 2017
# Fetched 365 days for Thakurgaon,Bangladesh 2018
# Fetched 365 days for Thakurgaon,Bangladesh 2019
# Fetched 366 days for Thakurgaon,Bangladesh 2020
# Fetched 365 days for Thakurgaon,Bangladesh 2021
# Fetched 365 days for Thakurgaon,Bangladesh 2022
# Fetched 365 days for Thakurgaon,Bangladesh 2023
# Fetched 366 days for Thakurgaon,Bangladesh 2024
# Saved 16437 records for Thakurgaon,Bangladesh to Thakurgaon_historical_weather_1980_2024.csv
